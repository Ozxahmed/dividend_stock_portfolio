# %% [markdown]
# 1. load env variables

# %%
# imports

from src.config import load_env_variable
from src.api_utils import get_fmp_api_data
import requests

# %% [markdown]
# - how do I access the fmp api?
#
# - what do I need for eps growth cagr?
#   - eps current, and eps 4 years ago
#   - we can get this from income statement. Income statement api end point url: https://financialmodelingprep.com/stable/income-statement
#   - Need to attach ticker, and api key
#
# - [x] Create a function that takes in a url, fetches the data, and returns a python json object? --> Done, function available in src/api_utils.py --> get_api_data(endpoint_url, api_key, ticker)
# - [ ] Use the function to get the income statement data for AAPL, and extract the eps values for the current year, and 4 years ago. --> Not done yet, need to test the function first.
